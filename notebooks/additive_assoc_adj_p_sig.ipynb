# %%
import pandas as pd

adj_p_df = pd.read_csv('../manuscript/additive_assoc_adj_p_all.csv')

thresh = 0.05
sig_df = adj_p_df.loc[(adj_p_df < thresh).sum(axis=1) > 0, :]
sig_df = sig_df[sig_df.columns[(sig_df< thresh).any()]]
print("number of phenotypes with significant entry: {}".format(sig_df.shape[0]))
print("number of allelotypes with significant entry: {}".format(sig_df.shape[1]))
sig_df.to_csv("additive_assoc_adj_p_sig.csv")
# Out:
# number of phenotypes with significant entry: 270
# number of allelotypes with significant entry: 114

# %%
adj_p_df
# Out:
#     Unnamed: 0  B_5101    B_5108        B_1501  B_1503      DRB3_301  \
# 0        HC139     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 1        HC134     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 2        HC135     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 3        HC136     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 4        HC131     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 5        HC132     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 6        HC133     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 7         1060     1.0  1.000000  1.000000e+00     1.0  1.232212e-01
# 8         1065     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 9         1085     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 10        1084     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 11        HC28     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# 12        HC25     1.0  1.000000  1.000000e+00     1.0  1.000000e+00
# ...

# %%
sig_df
# Out:
#     Unnamed: 0  B_5101        B_1501      DRB3_301      DQA1_101  \
# 0        HC139     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 1        HC134     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 2        HC135     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 3        HC136     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 4        HC131     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 5        HC132     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 6        HC133     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 7         1060     1.0  1.000000e+00  1.232212e-01  1.672825e-11
# 8         1065     1.0  1.000000e+00  1.000000e+00  8.538426e-01
# 9         1085     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 10        1084     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 11        HC28     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# 12        HC25     1.0  1.000000e+00  1.000000e+00  1.000000e+00
# ...
