# %%
import pandas as pd

# %%
dosage_response = pd.read_csv('/scratch/PI/mrivas/ukbb/24983/hla/ukb_hla_v2.txt', delimiter = '\t', header=0)

# %%
print(dosage_response)
# Out:
#            A_101  A_102  A_103     A_201  A_202  A_203  A_205  A_206  A_207  \
# 0       0.000000    0.0    0.0  1.993333    0.0   0.00    0.0    0.0    0.0
# 1       2.000000    0.0    0.0  0.000000    0.0   0.00    0.0    0.0    0.0
# 2       0.000000    0.0    0.0  0.000000    0.0   0.00    0.0    0.0    0.0
# 3       2.000000    0.0    0.0  0.000000    0.0   0.00    0.0    0.0    0.0
# 4       0.000000    0.0    0.0  1.000000    0.0   0.00    0.0    0.0    0.0
# 5       0.000000    0.0    0.0  1.000000    0.0   0.00    0.0    0.0    0.0
# 6       1.000000    0.0    0.0  0.000000    0.0   0.00    0.0    0.0    0.0
# 7       0.000000    0.0    0.0  2.000000    0.0   0.00    0.0    0.0    0.0
# 8       1.000000    0.0    0.0  0.000000    0.0   0.56    0.0    0.0    0.0
# 9       0.000000    0.0    0.0  2.000000    0.0   0.00    0.0    0.0    0.0
# 10      1.000000    0.0    0.0  0.000000    0.0   0.00    0.0    0.0    0.0
# ...

# %%
col = 'B_1512'
print(dosage_response[col][dosage_response[col].nonzero()[0]])
# Out:
# 48743     0.446667
# 253359    0.560000
# 334386    0.166667
# 354949    0.433333
# 407260    0.466667
# Name: B_1512, dtype: float64
