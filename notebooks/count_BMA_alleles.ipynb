# %%
import pandas as pd

# %%
path = "~/oak/users/jolivier/repos/hla-assoc/"
outpath = path + "notebooks/output/count_BMA_alleles/"

# %%
df = pd.read_csv(path + "notebooks/output/compare_cutoff_pvals/BMA_haps_100.csv", header=None, index_col = 0)
df
# Out:
#             1          2          3          4          5          6    \
# 0
# HC136  DRB1_404      B_801   DQA1_301   DQB1_302   DQA1_201   DRB1_701
# 1060   DQB1_501   DQA1_101   DRB1_101  DRB4_9901   DQB1_302      C_304
# HC28     A_2608   DRB1_701   DQB1_303   DQA1_201   DPB1_401        NaN
# HC25   DRB1_301   DQB1_201        NaN        NaN        NaN        NaN
# HC22   DQB1_201   DRB1_301        NaN        NaN        NaN        NaN
# HC422    B_2705      C_202      C_102   DRB1_103     B_2702   DRB1_101
# HC298  DQA1_301  DRB3_9901   DRB3_202        NaN        NaN        NaN
# HC170     B_801  DRB3_9901   DRB3_101      C_701   DQB1_201   DRB1_301
# HC179  DQB1_201   DRB1_301   DRB3_101   DQA1_501      B_801      C_701
# 1053      B_801   DRB1_301   DQB1_501   DQB1_201      C_701   DRB1_101
# 1055   DQA1_101   DQB1_501        NaN        NaN        NaN        NaN
# HC17   DQB1_201   DQB1_302   DRB1_301        NaN        NaN        NaN
# ...

# %%
count = df.count(axis=1)
to_rerun = count[count>30]
to_rerun
# Out:
# 0
# HC55     31
# HC303    74
# HC38     52
# HC430    41
# HC382    47
# HC219    71
# dtype: int64
